# %%
import pandas as pd
import shutil
import os

# %%
# read csv
df = pd.read_csv('audiomap.csv')

# %%
# clean data
df = df[df['audio0'].notna()]
df = df.iloc[:,1:]
df
# Out:
#       card ID                       name                     audio0  \
# 0    202098.0            Eyck of Densele  SAY.Battlecries_part4.148
# 1    202100.0               Prince Vilem  SAY.Battlecries_part4.158
# 2    202101.0             Count Caldwell  SAY.Battlecries_part4.153
# 3    202102.0             Xavier Lemmens  SAY.Battlecries_part4.163
# 4    202044.0               Gimpy Gerwin  SAY.Battlecries_part4.238
# ..        ...                        ...                        ...
# 838  203280.0        Eudora Breckenriggs       SAY.Battlecries.5501
# 839  203282.0  King Radovid V: Judgement       SAY.Battlecries.5485
# 840  203283.0                Lara Dorren       SAY.Battlecries.5506
# 841  203284.0                    Vereena       SAY.Battlecries.5511
# 843  203286.0    Madam Marquise Serenity       SAY.Battlecries.5516
#
#                         audio1                     audio2  \
# 0    SAY.Battlecries_part4.152  SAY.Battlecries_part4.151
# ...

# %%
# transform data
audio0 = df.iloc[:,:3]
audio0 = audio0.rename(columns={'audio0':'audio'})
audio0['suffix'] = '_1'
audio1 = df.iloc[:,:2].join(df['audio1'])
audio1 = audio1.rename(columns={'audio1':'audio'})
audio1['suffix'] = '_2'
audio2 = df.iloc[:,:2].join(df['audio2'])
audio2 = audio2.rename(columns={'audio2':'audio'})
audio2['suffix'] = '_3'
audio3 = df.iloc[:,:2].join(df['audio3'])
audio3 = audio3.rename(columns={'audio3':'audio'})
audio3['suffix'] = '_4'
audio4 = df.iloc[:,:2].join(df['audio4'])
audio4 = audio4.rename(columns={'audio4':'audio'})
audio4['suffix'] = '_5'
audio5 = df.iloc[:,:2].join(df['audio5'])
audio5 = audio5.rename(columns={'audio5':'audio'})
audio5['suffix'] = '_6'
audio6 = df.iloc[:,:2].join(df['audio6'])
audio6 = audio6.rename(columns={'audio6':'audio'})
audio6['suffix'] = '_7'
audio1

audio = pd.concat([audio0 , audio1, audio2, audio3, audio4, audio5, audio6])
audio = audio.dropna()
audio.head()
# Out:
#     card ID             name                      audio suffix
# 0  202098.0  Eyck of Densele  SAY.Battlecries_part4.148     _1
# 1  202100.0     Prince Vilem  SAY.Battlecries_part4.158     _1
# 2  202101.0   Count Caldwell  SAY.Battlecries_part4.153     _1
# 3  202102.0   Xavier Lemmens  SAY.Battlecries_part4.163     _1
# 4  202044.0     Gimpy Gerwin  SAY.Battlecries_part4.238     _1

# %% [markdown]
# Shorten Voiceline Names

# %%
# # read all images names in folder
# names = []
# for file in os.listdir('voicelinesCN'):
#         names.append(os.path.join(file))
# # shorten names
# shortnames = [name.split('-')[0] +'.mp3' for name in names]
# shortnames
# for i in range(len(names)):
#         os.rename(f"voicelinesCN\{names[i]}",f"voicelinesCN\{shortnames[i]}")
# audio.iloc[0,0]
# Out:
# 202098.0

# %%
for i in range(len(audio['audio'])):
    os.makedirs(f"Resources/Voicelines/CN/{int(audio.iloc[i,0])}",exist_ok=True)
    try :
        shutil.copyfile(f"voicelinesCN/{audio.iloc[i,2]}.mp3", f"Resources/Voicelines/CN/{int(audio.iloc[i,0])}/{int(audio.iloc[i,0])}{audio.iloc[i,3]}.mp3")
    except:
        pass
